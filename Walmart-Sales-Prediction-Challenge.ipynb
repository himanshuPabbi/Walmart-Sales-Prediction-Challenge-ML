# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
import xgboost as xgb

# %%
from sklearn.model_selection import train_test_split,KFold,cross_val_score

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
from sklearn.metrics import classification_report

# %%
df=pd.read_csv("Walmart.csv")

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df.shape
# Out:
# (6435, 8)

# %%
sns.boxplot(df['Store'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Store'>

# %%
sns.boxplot(df['Temperature'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Temperature'>

# %%
q1=df['Temperature'].quantile(0.25)

# %%
q3=df['Temperature'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Temperature']>lower) & (df['Temperature']<upper)]

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6432 rows x 8 columns]

# %%
sns.boxplot(df['Fuel_Price'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fuel_Price'>

# %%
sns.boxplot(df['CPI'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CPI'>

# %%
sns.boxplot(df['Unemployment'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Unemployment'>

# %%
q1=df['Unemployment'].quantile(0.25)

# %%
q3=df['Unemployment'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Unemployment']>lower) & (df['Unemployment']<upper)]

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [5951 rows x 8 columns]

# %%
sns.boxplot(df['Holiday_Flag'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Holiday_Flag'>

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [5951 rows x 8 columns]

# %%
df['Date']=pd.to_datetime(df['Date'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '16-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '23-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '30-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '18-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '25-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '22-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '29-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '27-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '24-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '31-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '19-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '26-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_26288\3104278362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date']=pd.to_datetime(df['Date'])

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [5951 rows x 8 columns]

# %%
df['Month']=df['Date'].dt.month
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_26288\1855346815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month']=df['Date'].dt.month

# %%
df['Year']=df['Date'].dt.year
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_26288\2632089269.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year']=df['Date'].dt.year

# %%
df['Day']=df['Date'].dt.day
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_26288\2634055668.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day']=df['Date'].dt.day

# %%
df['quarter'] = pd.PeriodIndex(df.Date, freq='Q')
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_26288\2850330586.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter'] = pd.PeriodIndex(df.Date, freq='Q')

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Month  Year  Day quarter
# 0     211.096358         8.106      5  2010    2  2010Q2
# 1     211.242170         8.106     12  2010    2  2010Q4
# 2     211.289143         8.106      2  2010   19  2010Q1
# 3     211.319643         8.106      2  2010   26  2010Q1
# 4     211.350143         8.106      5  2010    3  2010Q2
# ...          ...           ...    ...   ...  ...     ...
# 6430  192.013558         8.684      9  2012   28  2012Q3
# 6431  192.170412         8.667      5  2012   10  2012Q2
# 6432  192.327265         8.667     12  2012   10  2012Q4
# 6433  192.330854         8.667     10  2012   19  2012Q4
# 6434  192.308899         8.667     10  2012   26  2012Q4
#
# [5951 rows x 12 columns]

# %%
df['week']=df['Date'].dt.week
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_26288\475266402.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week']=df['Date'].dt.week
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_26288\475266402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['week']=df['Date'].dt.week

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Month  Year  Day quarter  week
# 0     211.096358         8.106      5  2010    2  2010Q2    17
# 1     211.242170         8.106     12  2010    2  2010Q4    48
# 2     211.289143         8.106      2  2010   19  2010Q1     7
# 3     211.319643         8.106      2  2010   26  2010Q1     8
# 4     211.350143         8.106      5  2010    3  2010Q2    18
# ...          ...           ...    ...   ...  ...     ...   ...
# 6430  192.013558         8.684      9  2012   28  2012Q3    39
# 6431  192.170412         8.667      5  2012   10  2012Q2    19
# 6432  192.327265         8.667     12  2012   10  2012Q4    50
# 6433  192.330854         8.667     10  2012   19  2012Q4    42
# 6434  192.308899         8.667     10  2012   26  2012Q4    43
#
# [5951 rows x 13 columns]

# %%
df['Day Of Week']=df['Date'].dt.day_of_week
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_26288\2895530276.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day Of Week']=df['Date'].dt.day_of_week

# %%
df['Day_Name']=df['Date'].dt.day_name()
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_26288\906889134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day_Name']=df['Date'].dt.day_name()

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Month  Year  Day quarter  week  Day Of Week  \
# 0     211.096358         8.106      5  2010    2  2010Q2    17            6
# 1     211.242170         8.106     12  2010    2  2010Q4    48            3
# 2     211.289143         8.106      2  2010   19  2010Q1     7            4
# 3     211.319643         8.106      2  2010   26  2010Q1     8            4
# 4     211.350143         8.106      5  2010    3  2010Q2    18            0
# ...          ...           ...    ...   ...  ...     ...   ...          ...
# 6430  192.013558         8.684      9  2012   28  2012Q3    39            4
# 6431  192.170412         8.667      5  2012   10  2012Q2    19            3
# 6432  192.327265         8.667     12  2012   10  2012Q4    50            0
# 6433  192.330854         8.667     10  2012   19  2012Q4    42            4
# 6434  192.308899         8.667     10  2012   26  2012Q4    43            4
#
#       Day_Name
# 0       Sunday
# 1     Thursday
# 2       Friday
# 3       Friday
# 4       Monday
# ...        ...
# 6430    Friday
# 6431  Thursday
# 6432    Monday
# 6433    Friday
# 6434    Friday
#
# [5951 rows x 15 columns]

# %%
df=df.drop('Date',axis=1)

# %%
df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name
# 0            8.106      5  2010    2  2010Q2    17            6    Sunday
# 1            8.106     12  2010    2  2010Q4    48            3  Thursday
# 2            8.106      2  2010   19  2010Q1     7            4    Friday
# 3            8.106      2  2010   26  2010Q1     8            4    Friday
# 4            8.106      5  2010    3  2010Q2    18            0    Monday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6430         8.684      9  2012   28  2012Q3    39            4    Friday
# 6431         8.667      5  2012   10  2012Q2    19            3  Thursday
# 6432         8.667     12  2012   10  2012Q4    50            0    Monday
# 6433         8.667     10  2012   19  2012Q4    42            4    Friday
# 6434         8.667     10  2012   26  2012Q4    43            4    Friday
#
# [5951 rows x 14 columns]

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['Store'],y=df['Weekly_Sales'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['Day_Name'],y=df['Weekly_Sales'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['Day_Name'],y=df['Weekly_Sales'],hue=df['Year'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['quarter'],y=df['Weekly_Sales'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['Store'],y=df['Weekly_Sales'],hue=df['Holiday_Flag'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['Day_Name'],y=df['Weekly_Sales'],hue=df['Holiday_Flag'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['quarter'],y=df['Weekly_Sales'],hue=df['Holiday_Flag'])
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name
# 0            8.106      5  2010    2  2010Q2    17            6    Sunday
# 1            8.106     12  2010    2  2010Q4    48            3  Thursday
# 2            8.106      2  2010   19  2010Q1     7            4    Friday
# 3            8.106      2  2010   26  2010Q1     8            4    Friday
# 4            8.106      5  2010    3  2010Q2    18            0    Monday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6430         8.684      9  2012   28  2012Q3    39            4    Friday
# 6431         8.667      5  2012   10  2012Q2    19            3  Thursday
# 6432         8.667     12  2012   10  2012Q4    50            0    Monday
# 6433         8.667     10  2012   19  2012Q4    42            4    Friday
# 6434         8.667     10  2012   26  2012Q4    43            4    Friday
#
# [5951 rows x 14 columns]

# %%
sns.barplot(x=df['Month'],y=df['Weekly_Sales'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Weekly_Sales'>

# %%
sns.barplot(x=df['Year'],y=df['Weekly_Sales'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Weekly_Sales'>

# %%
sns.barplot(x=df['Month'],y=df['Weekly_Sales'],hue=df['Holiday_Flag'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Weekly_Sales'>

# %%
sns.barplot(x=df['Year'],y=df['Weekly_Sales'],hue=df['Holiday_Flag'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Weekly_Sales'>

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['week'],y=df['Weekly_Sales'],hue=df['Holiday_Flag'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['Day Of Week'],y=df['Weekly_Sales'],hue=df['Holiday_Flag'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['week'],y=df['Weekly_Sales'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['Day Of Week'],y=df['Weekly_Sales'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['week'],y=df['Weekly_Sales'],hue=df['Year'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['Day Of Week'],y=df['Weekly_Sales'],hue=df['quarter'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['quarter'],y=df['Weekly_Sales'],hue=df['Year'])
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name
# 0            8.106      5  2010    2  2010Q2    17            6    Sunday
# 1            8.106     12  2010    2  2010Q4    48            3  Thursday
# 2            8.106      2  2010   19  2010Q1     7            4    Friday
# 3            8.106      2  2010   26  2010Q1     8            4    Friday
# 4            8.106      5  2010    3  2010Q2    18            0    Monday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6430         8.684      9  2012   28  2012Q3    39            4    Friday
# 6431         8.667      5  2012   10  2012Q2    19            3  Thursday
# 6432         8.667     12  2012   10  2012Q4    50            0    Monday
# 6433         8.667     10  2012   19  2012Q4    42            4    Friday
# 6434         8.667     10  2012   26  2012Q4    43            4    Friday
#
# [5951 rows x 14 columns]

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['Store'],y=df['Weekly_Sales'],hue=df['Year'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['Day_Name'],y=df['Weekly_Sales'],hue=df['Year'])
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name
# 0            8.106      5  2010    2  2010Q2    17            6    Sunday
# 1            8.106     12  2010    2  2010Q4    48            3  Thursday
# 2            8.106      2  2010   19  2010Q1     7            4    Friday
# 3            8.106      2  2010   26  2010Q1     8            4    Friday
# 4            8.106      5  2010    3  2010Q2    18            0    Monday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6430         8.684      9  2012   28  2012Q3    39            4    Friday
# 6431         8.667      5  2012   10  2012Q2    19            3  Thursday
# 6432         8.667     12  2012   10  2012Q4    50            0    Monday
# 6433         8.667     10  2012   19  2012Q4    42            4    Friday
# 6434         8.667     10  2012   26  2012Q4    43            4    Friday
#
# [5951 rows x 14 columns]

# %%
sns.lineplot(x=df['Day Of Week'],y=df['Weekly_Sales'])
# Out:
# <AxesSubplot:xlabel='Day Of Week', ylabel='Weekly_Sales'>

# %%
sns.lineplot(x=df['Day_Name'],y=df['Weekly_Sales'])
# Out:
# <AxesSubplot:xlabel='Day_Name', ylabel='Weekly_Sales'>

# %%
sns.lineplot(x=df['week'],y=df['Weekly_Sales'])
# Out:
# <AxesSubplot:xlabel='week', ylabel='Weekly_Sales'>

# %%
sns.lineplot(x=df['week'],y=df['Weekly_Sales'],hue=df['Holiday_Flag'])
# Out:
# <AxesSubplot:xlabel='week', ylabel='Weekly_Sales'>

# %%
sns.lineplot(x=df['Day Of Week'],y=df['Weekly_Sales'],hue=df['Holiday_Flag'])
# Out:
# <AxesSubplot:xlabel='Day Of Week', ylabel='Weekly_Sales'>

# %%
sns.lineplot(x=df['Day_Name'],y=df['Weekly_Sales'],hue=df['Holiday_Flag'])
# Out:
# <AxesSubplot:xlabel='Day_Name', ylabel='Weekly_Sales'>

# %%
sns.pairplot(data=df)

# %%
df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name
# 0            8.106      5  2010    2  2010Q2    17            6    Sunday
# 1            8.106     12  2010    2  2010Q4    48            3  Thursday
# 2            8.106      2  2010   19  2010Q1     7            4    Friday
# 3            8.106      2  2010   26  2010Q1     8            4    Friday
# 4            8.106      5  2010    3  2010Q2    18            0    Monday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6430         8.684      9  2012   28  2012Q3    39            4    Friday
# 6431         8.667      5  2012   10  2012Q2    19            3  Thursday
# 6432         8.667     12  2012   10  2012Q4    50            0    Monday
# 6433         8.667     10  2012   19  2012Q4    42            4    Friday
# 6434         8.667     10  2012   26  2012Q4    43            4    Friday
#
# [5951 rows x 14 columns]

# %%
df['Weekly_Sales_Range']=pd.qcut(df['Weekly_Sales'],4)

# %%
sns.barplot(x=df['Year'],y=df['Unemployment'],hue=df['Weekly_Sales_Range'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Unemployment'>

# %%
sns.barplot(x=df['Year'],y=df['Fuel_Price'],hue=df['Weekly_Sales_Range'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Fuel_Price'>

# %%
sns.barplot(x=df['Month'],y=df['Unemployment'],hue=df['Weekly_Sales_Range'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Unemployment'>

# %%
sns.barplot(x=df['Month'],y=df['Fuel_Price'],hue=df['Weekly_Sales_Range'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Fuel_Price'>

# %%
sns.barplot(x=df['Year'],y=df['CPI'],hue=df['Weekly_Sales_Range'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='CPI'>

# %%
sns.barplot(x=df['Month'],y=df['CPI'],hue=df['Weekly_Sales_Range'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='CPI'>

# %%
df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name  \
# 0            8.106      5  2010    2  2010Q2    17            6    Sunday
# 1            8.106     12  2010    2  2010Q4    48            3  Thursday
# 2            8.106      2  2010   19  2010Q1     7            4    Friday
# 3            8.106      2  2010   26  2010Q1     8            4    Friday
# 4            8.106      5  2010    3  2010Q2    18            0    Monday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6430         8.684      9  2012   28  2012Q3    39            4    Friday
# 6431         8.667      5  2012   10  2012Q2    19            3  Thursday
# 6432         8.667     12  2012   10  2012Q4    50            0    Monday
# 6433         8.667     10  2012   19  2012Q4    42            4    Friday
# 6434         8.667     10  2012   26  2012Q4    43            4    Friday
#
#              Weekly_Sales_Range
# 0     (1436633.915, 3818686.45]
# 1     (1436633.915, 3818686.45]
# 2     (1436633.915, 3818686.45]
# 3      (951549.61, 1436633.915]
# 4     (1436633.915, 3818686.45]
# ...                         ...
# 6430    (554064.995, 951549.61]
# 6431    (554064.995, 951549.61]
# 6432    (554064.995, 951549.61]
# 6433    (554064.995, 951549.61]
# 6434    (554064.995, 951549.61]
#
# [5951 rows x 15 columns]

# %%
sns.distplot(df['Temperature'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Temperature', ylabel='Density'>

# %%
sns.distplot(df['Fuel_Price'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fuel_Price', ylabel='Density'>

# %%
sns.distplot(df['Unemployment'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Unemployment', ylabel='Density'>

# %%
sns.distplot(df['CPI'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CPI', ylabel='Density'>

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name  \
# 0            8.106      5  2010    2  2010Q2    17            6    Sunday
# 1            8.106     12  2010    2  2010Q4    48            3  Thursday
# 2            8.106      2  2010   19  2010Q1     7            4    Friday
# 3            8.106      2  2010   26  2010Q1     8            4    Friday
# 4            8.106      5  2010    3  2010Q2    18            0    Monday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6430         8.684      9  2012   28  2012Q3    39            4    Friday
# 6431         8.667      5  2012   10  2012Q2    19            3  Thursday
# 6432         8.667     12  2012   10  2012Q4    50            0    Monday
# 6433         8.667     10  2012   19  2012Q4    42            4    Friday
# 6434         8.667     10  2012   26  2012Q4    43            4    Friday
#
#              Weekly_Sales_Range
# 0     (1436633.915, 3818686.45]
# 1     (1436633.915, 3818686.45]
# 2     (1436633.915, 3818686.45]
# 3      (951549.61, 1436633.915]
# 4     (1436633.915, 3818686.45]
# ...                         ...
# 6430    (554064.995, 951549.61]
# 6431    (554064.995, 951549.61]
# 6432    (554064.995, 951549.61]
# 6433    (554064.995, 951549.61]
# 6434    (554064.995, 951549.61]
#
# [5951 rows x 15 columns]

# %%
df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name  \
# 0            8.106      5  2010    2  2010Q2    17            6    Sunday
# 1            8.106     12  2010    2  2010Q4    48            3  Thursday
# 2            8.106      2  2010   19  2010Q1     7            4    Friday
# 3            8.106      2  2010   26  2010Q1     8            4    Friday
# 4            8.106      5  2010    3  2010Q2    18            0    Monday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6430         8.684      9  2012   28  2012Q3    39            4    Friday
# 6431         8.667      5  2012   10  2012Q2    19            3  Thursday
# 6432         8.667     12  2012   10  2012Q4    50            0    Monday
# 6433         8.667     10  2012   19  2012Q4    42            4    Friday
# 6434         8.667     10  2012   26  2012Q4    43            4    Friday
#
#              Weekly_Sales_Range
# 0     (1436633.915, 3818686.45]
# 1     (1436633.915, 3818686.45]
# 2     (1436633.915, 3818686.45]
# 3      (951549.61, 1436633.915]
# 4     (1436633.915, 3818686.45]
# ...                         ...
# 6430    (554064.995, 951549.61]
# 6431    (554064.995, 951549.61]
# 6432    (554064.995, 951549.61]
# 6433    (554064.995, 951549.61]
# 6434    (554064.995, 951549.61]
#
# [5951 rows x 15 columns]

# %% [markdown]
# # Top 10 Stores with Highest Weekly Sales in all Years

# %%
label_df=df.groupby("Store")['Weekly_Sales'].mean().sort_values(ascending=False).index

# %%
label_df
# Out:
# Int64Index([20,  4, 14, 13,  2, 10, 27,  6,  1, 39, 19, 23, 31, 24, 11, 41, 28,
#             32, 18, 22, 26, 40, 34, 12, 35,  8, 17, 45, 21, 25, 43, 15,  7, 42,
#              9, 29, 16, 37, 30, 38,  3, 36,  5, 44, 33],
#            dtype='int64', name='Store')

# %%
value_df=df.groupby("Store")['Weekly_Sales'].mean().sort_values(ascending=False).values

# %%
value_df
# Out:
# array([2107676.87034965, 2088551.09611111, 2020978.40097902,
#        2003620.30629371, 1925751.33552448, 1899424.57265734,
#        1775216.20195804, 1564728.18629371, 1555264.39755245,
#        1450668.12916084, 1444999.03566434, 1399826.391     ,
#        1395901.43706294, 1356755.39356643, 1356383.12447552,
#        1268125.41881119, 1241574.57647059, 1166568.15496503,
#        1084718.42104895, 1028501.03895105, 1004217.6665493 ,
#         966979.0245    ,  966781.55944056,  963924.16411765,
#         919724.97958042,  908749.51839161,  892246.95556338,
#         785981.40853147,  756069.08335664,  706721.53265734,
#         633324.72314685,  623312.47496503,  570705.96739437,
#         556403.86314685,  543980.55237762,  539451.42874126,
#         519247.73006993,  518900.28195804,  438579.61622378,
#         432198.75823529,  402704.44104895,  373511.9927972 ,
#         318011.81048951,  302748.86601399,  259861.69202797])

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=label_df[:10],y=value_df[:10])
# Out:
# <AxesSubplot:xlabel='Store'>

# %% [markdown]
# # Bottom 10 Stores with Lowest Weekly Sales in all Years

# %%
label_df=df.groupby("Store")['Weekly_Sales'].mean().sort_values(ascending=True).index

# %%
label_df
# Out:
# Int64Index([33, 44,  5, 36,  3, 38, 30, 37, 16, 29,  9, 42,  7, 15, 43, 25, 21,
#             45, 17,  8, 35, 12, 34, 40, 26, 22, 18, 32, 28, 41, 11, 24, 31, 23,
#             19, 39,  1,  6, 27, 10,  2, 13, 14,  4, 20],
#            dtype='int64', name='Store')

# %%
value_df=df.groupby("Store")['Weekly_Sales'].mean().sort_values(ascending=True).values

# %%
value_df
# Out:
# array([ 259861.69202797,  302748.86601399,  318011.81048951,
#         373511.9927972 ,  402704.44104895,  432198.75823529,
#         438579.61622378,  518900.28195804,  519247.73006993,
#         539451.42874126,  543980.55237762,  556403.86314685,
#         570705.96739437,  623312.47496503,  633324.72314685,
#         706721.53265734,  756069.08335664,  785981.40853147,
#         892246.95556338,  908749.51839161,  919724.97958042,
#         963924.16411765,  966781.55944056,  966979.0245    ,
#        1004217.6665493 , 1028501.03895105, 1084718.42104895,
#        1166568.15496503, 1241574.57647059, 1268125.41881119,
#        1356383.12447552, 1356755.39356643, 1395901.43706294,
#        1399826.391     , 1444999.03566434, 1450668.12916084,
#        1555264.39755245, 1564728.18629371, 1775216.20195804,
#        1899424.57265734, 1925751.33552448, 2003620.30629371,
#        2020978.40097902, 2088551.09611111, 2107676.87034965])

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=label_df[:10],y=value_df[:10])
# Out:
# <AxesSubplot:xlabel='Store'>

# %% [markdown]
# # Top 10 Stores with highest Weekly Sales for the year 2012

# %%
year_2012_df=df.groupby("Year").get_group(2012)

# %%
year_2012_df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 100       1    1550369.92             0        49.01       3.157  219.714258
# 101       1    1459601.17             0        48.53       3.261  219.892526
# 102       1    1394393.84             0        54.11       3.268  219.985689
# 103       1    1319325.59             0        54.26       3.290  220.078852
# 104       1    1636339.65             0        56.55       3.360  220.172015
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name  \
# 100          7.348      6  2012    1  2012Q2    22            4    Friday
# 101          7.348      1  2012   13  2012Q1     2            4    Friday
# 102          7.348      1  2012   20  2012Q1     3            4    Friday
# 103          7.348      1  2012   27  2012Q1     4            4    Friday
# 104          7.348      3  2012    2  2012Q1     9            4    Friday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6430         8.684      9  2012   28  2012Q3    39            4    Friday
# 6431         8.667      5  2012   10  2012Q2    19            3  Thursday
# 6432         8.667     12  2012   10  2012Q4    50            0    Monday
# 6433         8.667     10  2012   19  2012Q4    42            4    Friday
# 6434         8.667     10  2012   26  2012Q4    43            4    Friday
#
#              Weekly_Sales_Range
# 100   (1436633.915, 3818686.45]
# 101   (1436633.915, 3818686.45]
# 102    (951549.61, 1436633.915]
# 103    (951549.61, 1436633.915]
# 104   (1436633.915, 3818686.45]
# ...                         ...
# 6430    (554064.995, 951549.61]
# 6431    (554064.995, 951549.61]
# 6432    (554064.995, 951549.61]
# 6433    (554064.995, 951549.61]
# 6434    (554064.995, 951549.61]
#
# [1754 rows x 15 columns]

# %%
label_df=year_2012_df.groupby("Store")['Weekly_Sales'].mean().sort_values(ascending=False).index

# %%
label_df
# Out:
# Int64Index([ 4, 20, 13,  2, 10, 14, 27,  1,  6, 39, 31, 19, 11, 24, 41, 28, 32,
#             18, 26, 22, 34, 12, 17,  8, 35, 45, 21, 25, 43,  7, 42, 15,  9, 37,
#             29, 16, 30, 38,  3, 44,  5, 36, 33],
#            dtype='int64', name='Store')

# %%
value_df=year_2012_df.groupby("Store")['Weekly_Sales'].mean().sort_values(ascending=False).values

# %%
value_df
# Out:
# array([2168641.30653846, 2089016.4972093 , 2016452.44232558,
#        1895271.98534884, 1819270.16139535, 1800962.75023256,
#        1672559.44465116, 1586094.37255814, 1542210.39534884,
#        1532224.71744186, 1392660.63302326, 1377033.33209302,
#        1353117.80651163, 1329916.19      , 1322973.02162791,
#        1241574.57647059, 1169328.27906977, 1044618.06511628,
#         999452.1927907 ,  991992.00534884,  970678.23604651,
#         963924.16411765,  936869.27046512,  912416.7472093 ,
#         819481.91906977,  761014.65511628,  703532.24906977,
#         685825.71418605,  627331.02255814,  589943.17372093,
#         580240.92674419,  577384.43511628,  557535.57162791,
#         525878.48116279,  517311.20046512,  514009.89116279,
#         437108.14139535,  432198.75823529,  419173.01162791,
#         329938.92372093,  329507.86348837,  308987.68674419,
#         265943.0472093 ])

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=label_df[:10],y=value_df[:10])
# Out:
# <AxesSubplot:xlabel='Store'>

# %% [markdown]
# # Highest Weekly Sales on Holiday in which Year

# %%
df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name  \
# 0            8.106      5  2010    2  2010Q2    17            6    Sunday
# 1            8.106     12  2010    2  2010Q4    48            3  Thursday
# 2            8.106      2  2010   19  2010Q1     7            4    Friday
# 3            8.106      2  2010   26  2010Q1     8            4    Friday
# 4            8.106      5  2010    3  2010Q2    18            0    Monday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6430         8.684      9  2012   28  2012Q3    39            4    Friday
# 6431         8.667      5  2012   10  2012Q2    19            3  Thursday
# 6432         8.667     12  2012   10  2012Q4    50            0    Monday
# 6433         8.667     10  2012   19  2012Q4    42            4    Friday
# 6434         8.667     10  2012   26  2012Q4    43            4    Friday
#
#              Weekly_Sales_Range
# 0     (1436633.915, 3818686.45]
# 1     (1436633.915, 3818686.45]
# 2     (1436633.915, 3818686.45]
# 3      (951549.61, 1436633.915]
# 4     (1436633.915, 3818686.45]
# ...                         ...
# 6430    (554064.995, 951549.61]
# 6431    (554064.995, 951549.61]
# 6432    (554064.995, 951549.61]
# 6433    (554064.995, 951549.61]
# 6434    (554064.995, 951549.61]
#
# [5951 rows x 15 columns]

# %%
holiday_df=df.groupby("Holiday_Flag").get_group(1)

# %%
holiday_df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 31        1    1507460.69             1        78.69       2.565  211.495190
# 42        1    1955624.11             1        64.52       2.735  211.748433
# 47        1    1367320.01             1        48.43       2.943  211.404932
# 53        1    1649614.93             1        36.39       3.022  212.936705
# ...     ...           ...           ...          ...         ...         ...
# 6375     45     746129.56             1        71.48       3.738  186.673738
# 6386     45    1170672.94             1        48.71       3.492  188.350400
# 6391     45     869403.63             1        37.79       3.389  189.062016
# 6397     45     803657.12             1        37.00       3.640  189.707605
# 6427     45     766512.66             1        75.70       3.911  191.577676
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week   Day_Name  \
# 1            8.106     12  2010    2  2010Q4    48            3   Thursday
# 31           7.787     10  2010    9  2010Q4    40            5   Saturday
# 42           7.838     11  2010   26  2010Q4    47            4     Friday
# 47           7.838     12  2010   31  2010Q4    52            4     Friday
# 53           7.742     11  2011    2  2011Q4    44            2  Wednesday
# ...            ...    ...   ...  ...     ...   ...          ...        ...
# 6375         8.625      9  2011    9  2011Q3    36            4     Friday
# 6386         8.523     11  2011   25  2011Q4    47            4     Friday
# 6391         8.523     12  2011   30  2011Q4    52            4     Friday
# 6397         8.424     10  2012    2  2012Q4    40            1    Tuesday
# 6427         8.684      7  2012    9  2012Q3    28            0     Monday
#
#              Weekly_Sales_Range
# 1     (1436633.915, 3818686.45]
# 31    (1436633.915, 3818686.45]
# 42    (1436633.915, 3818686.45]
# 47     (951549.61, 1436633.915]
# 53    (1436633.915, 3818686.45]
# ...                         ...
# 6375    (554064.995, 951549.61]
# 6386   (951549.61, 1436633.915]
# 6391    (554064.995, 951549.61]
# 6397    (554064.995, 951549.61]
# 6427    (554064.995, 951549.61]
#
# [418 rows x 15 columns]

# %%
label_df=holiday_df.groupby("Year")['Weekly_Sales'].mean().sort_values(ascending=False).index

# %%
value_df=holiday_df.groupby("Year")['Weekly_Sales'].mean().sort_values(ascending=False).values

# %%
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Highest Weekly Sales on NON-Holiday in which Year

# %%
non_holiday_df=df.groupby("Holiday_Flag").get_group(0)

# %%
non_holiday_df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# 5         1    1439541.59             0        57.79       2.667  211.380643
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name  \
# 0            8.106      5  2010    2  2010Q2    17            6    Sunday
# 2            8.106      2  2010   19  2010Q1     7            4    Friday
# 3            8.106      2  2010   26  2010Q1     8            4    Friday
# 4            8.106      5  2010    3  2010Q2    18            0    Monday
# 5            8.106     12  2010    3  2010Q4    48            4    Friday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6430         8.684      9  2012   28  2012Q3    39            4    Friday
# 6431         8.667      5  2012   10  2012Q2    19            3  Thursday
# 6432         8.667     12  2012   10  2012Q4    50            0    Monday
# 6433         8.667     10  2012   19  2012Q4    42            4    Friday
# 6434         8.667     10  2012   26  2012Q4    43            4    Friday
#
#              Weekly_Sales_Range
# 0     (1436633.915, 3818686.45]
# 2     (1436633.915, 3818686.45]
# 3      (951549.61, 1436633.915]
# 4     (1436633.915, 3818686.45]
# 5     (1436633.915, 3818686.45]
# ...                         ...
# 6430    (554064.995, 951549.61]
# 6431    (554064.995, 951549.61]
# 6432    (554064.995, 951549.61]
# 6433    (554064.995, 951549.61]
# 6434    (554064.995, 951549.61]
#
# [5533 rows x 15 columns]

# %%
label_df=non_holiday_df.groupby("Year")['Weekly_Sales'].mean().sort_values(ascending=False).index

# %%
value_df=non_holiday_df.groupby("Year")['Weekly_Sales'].mean().sort_values(ascending=False).values

# %%
plt.pie(x=value_df,labels=label_df,autopct="%1.2f%%")
plt.show()

# %%
df.columns
# Out:
# Index(['Store', 'Weekly_Sales', 'Holiday_Flag', 'Temperature', 'Fuel_Price',
#        'CPI', 'Unemployment', 'Month', 'Year', 'Day', 'quarter', 'week',
#        'Day Of Week', 'Day_Name', 'Weekly_Sales_Range'],
#       dtype='object')

# %% [markdown]
# # Find Average Weekly Sales for the year 2011 for Month 5

# %%
df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name  \
# 0            8.106      5  2010    2  2010Q2    17            6    Sunday
# 1            8.106     12  2010    2  2010Q4    48            3  Thursday
# 2            8.106      2  2010   19  2010Q1     7            4    Friday
# 3            8.106      2  2010   26  2010Q1     8            4    Friday
# 4            8.106      5  2010    3  2010Q2    18            0    Monday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6430         8.684      9  2012   28  2012Q3    39            4    Friday
# 6431         8.667      5  2012   10  2012Q2    19            3  Thursday
# 6432         8.667     12  2012   10  2012Q4    50            0    Monday
# 6433         8.667     10  2012   19  2012Q4    42            4    Friday
# 6434         8.667     10  2012   26  2012Q4    43            4    Friday
#
#              Weekly_Sales_Range
# 0     (1436633.915, 3818686.45]
# 1     (1436633.915, 3818686.45]
# 2     (1436633.915, 3818686.45]
# 3      (951549.61, 1436633.915]
# 4     (1436633.915, 3818686.45]
# ...                         ...
# 6430    (554064.995, 951549.61]
# 6431    (554064.995, 951549.61]
# 6432    (554064.995, 951549.61]
# 6433    (554064.995, 951549.61]
# 6434    (554064.995, 951549.61]
#
# [5951 rows x 15 columns]

# %%
year_2011_df=df.groupby("Year").get_group(2011)

# %%
year_2011_df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 48        1    1444732.28             0        48.27       2.976  211.404742
# 49        1    1391013.96             0        35.40       2.983  211.457411
# 50        1    1327405.42             0        44.04       3.016  211.827234
# 51        1    1316899.31             0        43.83       3.010  212.197058
# 52        1    1606629.58             0        42.27       2.989  212.566881
# ...     ...           ...           ...          ...         ...         ...
# 6387     45     875699.81             0        50.19       3.452  188.502435
# 6388     45     957155.31             0        46.57       3.415  188.654469
# 6389     45    1078905.68             0        39.93       3.413  188.797935
# 6390     45    1521957.99             0        42.27       3.389  188.929975
# 6391     45     869403.63             1        37.79       3.389  189.062016
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week  Day_Name  \
# 48           7.742      7  2011    1  2011Q3    26            4    Friday
# 49           7.742      1  2011   14  2011Q1     2            4    Friday
# 50           7.742      1  2011   21  2011Q1     3            4    Friday
# 51           7.742      1  2011   28  2011Q1     4            4    Friday
# 52           7.742      4  2011    2  2011Q2    13            5  Saturday
# ...            ...    ...   ...  ...     ...   ...          ...       ...
# 6387         8.523      2  2011   12  2011Q1     6            5  Saturday
# 6388         8.523      9  2011   12  2011Q3    37            0    Monday
# 6389         8.523     12  2011   16  2011Q4    50            4    Friday
# 6390         8.523     12  2011   23  2011Q4    51            4    Friday
# 6391         8.523     12  2011   30  2011Q4    52            4    Friday
#
#              Weekly_Sales_Range
# 48    (1436633.915, 3818686.45]
# 49     (951549.61, 1436633.915]
# 50     (951549.61, 1436633.915]
# 51     (951549.61, 1436633.915]
# 52    (1436633.915, 3818686.45]
# ...                         ...
# 6387    (554064.995, 951549.61]
# 6388   (951549.61, 1436633.915]
# 6389   (951549.61, 1436633.915]
# 6390  (1436633.915, 3818686.45]
# 6391    (554064.995, 951549.61]
#
# [2181 rows x 15 columns]

# %%
month_5_df=year_2011_df.groupby("Month").get_group(5)

# %%
month_5_df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 66        1    1604775.58             0        75.64       3.899  215.964053
# 67        1    1428218.27             0        67.63       3.907  215.733920
# 68        1    1466046.67             0        77.72       3.786  215.503788
# 78        1    1624383.75             0        91.65       3.684  215.544618
# 209       2    1838513.07             0        74.61       3.899  215.612473
# ...     ...           ...           ...          ...         ...         ...
# 6227     44     298080.45             0        75.56       3.595  129.184645
# 6358     45     793889.10             0        60.38       4.066  186.071923
# 6359     45     727163.67             0        62.28       4.062  185.966115
# 6360     45     817653.25             0        69.70       3.985  185.860308
# 6370     45     765996.92             0        78.22       3.842  186.373404
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week Day_Name  \
# 66           7.682      5  2011   13  2011Q2    19            4   Friday
# 67           7.682      5  2011   20  2011Q2    20            4   Friday
# 68           7.682      5  2011   27  2011Q2    21            4   Friday
# 78           7.962      5  2011    8  2011Q2    18            6   Sunday
# 209          7.931      5  2011   13  2011Q2    19            4   Friday
# ...            ...    ...   ...  ...     ...   ...          ...      ...
# 6227         6.560      5  2011    8  2011Q2    18            6   Sunday
# 6358         8.521      5  2011   13  2011Q2    19            4   Friday
# 6359         8.521      5  2011   20  2011Q2    20            4   Friday
# 6360         8.521      5  2011   27  2011Q2    21            4   Friday
# 6370         8.625      5  2011    8  2011Q2    18            6   Sunday
#
#              Weekly_Sales_Range
# 66    (1436633.915, 3818686.45]
# 67     (951549.61, 1436633.915]
# 68    (1436633.915, 3818686.45]
# 78    (1436633.915, 3818686.45]
# 209   (1436633.915, 3818686.45]
# ...                         ...
# 6227   (209986.249, 554064.995]
# 6358    (554064.995, 951549.61]
# 6359    (554064.995, 951549.61]
# 6360    (554064.995, 951549.61]
# 6370    (554064.995, 951549.61]
#
# [168 rows x 15 columns]

# %%
sns.barplot(x=month_5_df['Day Of Week'],y=month_5_df['Weekly_Sales'])
# Out:
# <AxesSubplot:xlabel='Day Of Week', ylabel='Weekly_Sales'>

# %%
sns.barplot(x=month_5_df['week'],y=month_5_df['Weekly_Sales'])
# Out:
# <AxesSubplot:xlabel='week', ylabel='Weekly_Sales'>

# %%
sns.barplot(x=month_5_df['Day'],y=month_5_df['Weekly_Sales'])
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Weekly_Sales'>

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=month_5_df['Store'],y=month_5_df['Weekly_Sales'])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=month_5_df['Store'],y=month_5_df['Weekly_Sales'],hue=month_5_df['Day Of Week'])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=month_5_df['Store'],y=month_5_df['Weekly_Sales'],hue=month_5_df['week'])
plt.show()

# %%
month_5_df
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 66        1    1604775.58             0        75.64       3.899  215.964053
# 67        1    1428218.27             0        67.63       3.907  215.733920
# 68        1    1466046.67             0        77.72       3.786  215.503788
# 78        1    1624383.75             0        91.65       3.684  215.544618
# 209       2    1838513.07             0        74.61       3.899  215.612473
# ...     ...           ...           ...          ...         ...         ...
# 6227     44     298080.45             0        75.56       3.595  129.184645
# 6358     45     793889.10             0        60.38       4.066  186.071923
# 6359     45     727163.67             0        62.28       4.062  185.966115
# 6360     45     817653.25             0        69.70       3.985  185.860308
# 6370     45     765996.92             0        78.22       3.842  186.373404
#
#       Unemployment  Month  Year  Day quarter  week  Day Of Week Day_Name  \
# 66           7.682      5  2011   13  2011Q2    19            4   Friday
# 67           7.682      5  2011   20  2011Q2    20            4   Friday
# 68           7.682      5  2011   27  2011Q2    21            4   Friday
# 78           7.962      5  2011    8  2011Q2    18            6   Sunday
# 209          7.931      5  2011   13  2011Q2    19            4   Friday
# ...            ...    ...   ...  ...     ...   ...          ...      ...
# 6227         6.560      5  2011    8  2011Q2    18            6   Sunday
# 6358         8.521      5  2011   13  2011Q2    19            4   Friday
# 6359         8.521      5  2011   20  2011Q2    20            4   Friday
# 6360         8.521      5  2011   27  2011Q2    21            4   Friday
# 6370         8.625      5  2011    8  2011Q2    18            6   Sunday
#
#              Weekly_Sales_Range
# 66    (1436633.915, 3818686.45]
# 67     (951549.61, 1436633.915]
# 68    (1436633.915, 3818686.45]
# 78    (1436633.915, 3818686.45]
# 209   (1436633.915, 3818686.45]
# ...                         ...
# 6227   (209986.249, 554064.995]
# 6358    (554064.995, 951549.61]
# 6359    (554064.995, 951549.61]
# 6360    (554064.995, 951549.61]
# 6370    (554064.995, 951549.61]
#
# [168 rows x 15 columns]

# %%
sns.scatterplot(x=month_5_df['Weekly_Sales'],y=month_5_df['Unemployment'])
# Out:
# <AxesSubplot:xlabel='Weekly_Sales', ylabel='Unemployment'>

# %%
sns.scatterplot(x=month_5_df['Weekly_Sales'],y=month_5_df['Temperature'])
# Out:
# <AxesSubplot:xlabel='Weekly_Sales', ylabel='Temperature'>

# %%
df=df.drop(['Weekly_Sales_Range','Day_Name','quarter','Fuel_Price'],axis=1)

# %%
y=df['Weekly_Sales']

# %%
X=df.drop('Weekly_Sales',axis=1)

# %%
sc=StandardScaler()

# %%
X=sc.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (4760, 10)

# %%
X_test.shape
# Out:
# (1191, 10)

# %% [markdown]
# # RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=rfr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.952772072832994

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 16530246296.194798

# %%
y_pred=rfr.predict(X_train)

# %%
r2_score(y_train,y_pred)
# Out:
# 0.9934592390264503

# %%
kf=KFold(5)

# %%
scores=cross_val_score(rfr,X_train,y_train,cv=kf)

# %%
for idx,value in enumerate(scores):
    print(idx,value)
# Out:
# 0 0.9472623300908315
# 1 0.9550162414035365
# 2 0.9603863685913394
# 3 0.9441154459088603
# 4 0.9426776888259296

# %%
scores.mean()
# Out:
# 0.9498916149640995

# %% [markdown]
# # LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.15693496382560201

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 295081184537.1244

# %%
y_pred=lr.predict(X_train)

# %%
r2_score(y_train,y_pred)
# Out:
# 0.12842067936049895

# %%
mean_squared_error(y_train,y_pred)
# Out:
# 280483652237.2149

# %%
kf=KFold(5)

# %%
scores=cross_val_score(lr,X_train,y_train,cv=kf)

# %%
for idx,value in enumerate(scores):
    print(idx,value)
# Out:
# 0 0.12711426256472502
# 1 0.0971025263262919
# 2 0.12056945019332521
# 3 0.12403813774786676
# 4 0.14833049063354953

# %%
scores.mean()
# Out:
# 0.12343097349315169

# %% [markdown]
# # DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dtr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9241534711204064

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 26547042783.766872

# %%
y_pred=dtr.predict(X_train)

# %%
r2_score(y_train,y_pred)
# Out:
# 1.0

# %%
kf=KFold(5)

# %%
scores=cross_val_score(dtr,X_train,y_train,cv=kf)

# %%
for idx,value in enumerate(scores):
    print(idx,value)
# Out:
# 0 0.9110580552686282
# 1 0.9235099897954226
# 2 0.9431258438452419
# 3 0.9002738438609343
# 4 0.9144139053719218

# %%
scores.mean()
# Out:
# 0.9184763276284297

# %% [markdown]
# # XGBRegressor

# %%
xgb_i=xgb.XGBRegressor()

# %%
xgb_i.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred=xgb_i.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9762393619648309

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 8316460671.398521

# %%
y_pred=xgb_i.predict(X_train)

# %%
r2_score(y_train,y_pred)
# Out:
# 0.9972592514921066

# %%
mean_squared_error(y_train,y_pred)
# Out:
# 882002513.3152634

# %%
kf=KFold(5)

# %%
scores=cross_val_score(xgb_i,X_train,y_train,cv=kf)

# %%
for idx,value in enumerate(scores):
    print(idx,value)
# Out:
# 0 0.9768936954533559
# 1 0.9797569150992822
# 2 0.9801648656654074
# 3 0.9657899516421884
# 4 0.9647701731010708

# %%
scores.mean()
# Out:
# 0.9734751201922609

# %% [markdown]
# # KNeighborsRegressor

# %%
knr=KNeighborsRegressor()

# %%
knr.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred=knr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.2526284425020404

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 261587511061.52283

# %%
y_pred=knr.predict(X_train)

# %%
r2_score(y_train,y_pred)
# Out:
# 0.5000816157747611

# %%
mean_squared_error(y_train,y_pred)
# Out:
# 160879143076.89166

# %%
kf=KFold(5)

# %%
scores=cross_val_score(knr,X_train,y_train,cv=kf)

# %%
for idx,value in enumerate(scores):
    print(idx,value)
# Out:
# 0 0.24927300545598108
# 1 0.25127258024293087
# 2 0.22208391031424657
# 3 0.21571687721548483
# 4 0.28073817672058243

# %%
scores.mean()
# Out:
# 0.24381690998984515
